# %%
# Importing the necessary libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Importing the data

data1 = pd.read_excel("Airbnb Dataset 19.xlsx")

# %% [markdown]
# ## Working with first dataframe -

# %%
data1
# Out:
#         Id                                              Name  Host_Id  \
# 0     2539                Clean & Quiet Apt Home By The Park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               The Village Of Harlem....New York !     4632
# 3     3831                   Cozy Entire Floor Of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft By Central Park     7192
# ..     ...                                               ...      ...
# 244  61492          Exclusive Room With Private Bath In  Les   297769
# 245  61509               Quiet, Clean Midtown Apt W. Elevato    23619
# 246  62095                 Bk Sweet Suite W/Kitchen&Fullbath   281764
# 247  62427               Great East Village Apartment Rental   303882
# 248  62430                     Brownstone Sundrenched Beauty   197755
#
#         Host_Name Neighbourhood_Group  Neighbourhood  Latitude  Longitude  \
# ...

# %%
# Checking the shape of the data

data1.shape
# Out:
# (249, 16)

# %%
# Checking the column names

data1.columns
# Out:
# Index(['Id', 'Name', 'Host_Id', 'Host_Name', 'Neighbourhood_Group',
#        'Neighbourhood', 'Latitude', 'Longitude', 'Room_Type', 'Price($)',
#        'Minimum_Nights', 'Number_Of_Reviews', 'Last_Review',
#        'Reviews_Per_Month', 'Calculated_Host_Listings_Count',
#        'Availability_365'],
#       dtype='object')

# %%
# Statistics of the numerical data

data1.describe()
# Out:
#                  Id       Host_Id    Latitude   Longitude    Price($)  \
# count    249.000000  2.490000e+02  249.000000  249.000000  249.000000
# mean   31376.771084  1.499884e+05   40.730257  -73.964044  143.971888
# std    18101.018309  4.010393e+05    0.049660    0.029685   91.442975
# min     2539.000000  2.787000e+03   40.631880  -74.080880   35.000000
# 25%    15711.000000  5.014800e+04   40.688430  -73.984980   85.000000
# 50%    28321.000000  9.779700e+04   40.721620  -73.964280  125.000000
# 75%    46911.000000  1.936370e+05   40.761930  -73.948220  175.000000
# max    62430.000000  6.197784e+06   40.867540  -73.765970  800.000000
#
#        Minimum_Nights  Number_Of_Reviews  Reviews_Per_Month  \
# count      249.000000         249.000000         242.000000
# mean         8.718876         103.445783           1.091653
# std         20.398680         100.337887           1.000168
# min          1.000000           0.000000           0.010000
# ...

# %%
# Statisctics of categorical data

cat_col = data1.select_dtypes("object").columns
data1[cat_col].describe()
# Out:
#                                       Name Host_Name Neighbourhood_Group  \
# count                                  249       249                 249
# unique                                 249       204                   5
# top     Clean & Quiet Apt Home By The Park      Mark           Manhattan
# freq                                     1         6                 124
#
#        Neighbourhood        Room_Type
# count            249              249
# unique            55                3
# top     Williamsburg  Entire home/apt
# freq              26              134

# %%
# Looking at the null values

data1.isnull().sum()
# Out:
# Id                                0
# Name                              0
# Host_Id                           0
# Host_Name                         0
# Neighbourhood_Group               0
# Neighbourhood                     0
# Latitude                          0
# Longitude                         0
# Room_Type                         0
# Price($)                          0
# Minimum_Nights                    0
# Number_Of_Reviews                 0
# Last_Review                       7
# Reviews_Per_Month                 7
# Calculated_Host_Listings_Count    0
# Availability_365                  0
# dtype: int64

# %%
# Filling the Null values

data1.fillna({"Last_Review":0,"Reviews_Per_Month":0},inplace=True)

# %%
# Looking at the datatypes 

data1.dtypes
# Out:
# Id                                  int64
# Name                               object
# Host_Id                             int64
# Host_Name                          object
# Neighbourhood_Group                object
# Neighbourhood                      object
# Latitude                          float64
# Longitude                         float64
# Room_Type                          object
# Price($)                            int64
# Minimum_Nights                      int64
# Number_Of_Reviews                   int64
# Last_Review                        object
# Reviews_Per_Month                 float64
# Calculated_Host_Listings_Count      int64
# Availability_365                    int64
# dtype: object

# %%
# Detecting the columns which are not usefull in the analysis

data1["Id"].describe()
# Out:
# count      249.000000
# mean     31376.771084
# std      18101.018309
# min       2539.000000
# 25%      15711.000000
# 50%      28321.000000
# 75%      46911.000000
# max      62430.000000
# Name: Id, dtype: float64

# %%
# Looking at the categories of the same column
"""As every row has different id thats why it is not useful in analysis"""

data1["Id"].value_counts()
# Out:
# 2539     1
# 44096    1
# 38663    1
# 39267    1
# 39282    1
#         ..
# 20300    1
# 20611    1
# 20724    1
# 20734    1
# 62430    1
# Name: Id, Length: 249, dtype: int64

# %%
# Deleting the "Id" column

del data1["Id"]

# %%
data1.head(3)
# Out:
#                                   Name  Host_Id  Host_Name  \
# 0   Clean & Quiet Apt Home By The Park     2787       John
# 1                Skylit Midtown Castle     2845   Jennifer
# 2  The Village Of Harlem....New York !     4632  Elisabeth
#
#   Neighbourhood_Group Neighbourhood  Latitude  Longitude        Room_Type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    Price($)  Minimum_Nights  Number_Of_Reviews          Last_Review  \
# 0       149               1                  9  2018-10-19 00:00:00
# 1       225               1                 45  2019-05-21 00:00:00
# 2       150               3                  0                    0
#
#    Reviews_Per_Month  Calculated_Host_Listings_Count  Availability_365
# 0               0.21                               6               365
# ...

# %%
# Checing for "name"
"""Here also every row has different name. Thats why it is also not important in anylysis"""

data1["Name"].describe()
# Out:
# count                                    249
# unique                                   249
# top       Clean & Quiet Apt Home By The Park
# freq                                       1
# Name: Name, dtype: object

# %%
# Deleting the "name" column

del data1["Name"]

# %%
# Analyzing "Host_Id" and "Host_Name"

data1["Host_Id"].value_counts()
# Out:
# 204539    5
# 126607    3
# 256161    3
# 32294     3
# 9744      3
#          ..
# 74303     1
# 74857     1
# 62407     1
# 76627     1
# 197755    1
# Name: Host_Id, Length: 218, dtype: int64

# %%
data1["Host_Name"].value_counts()
# Out:
# Mark       6
# Lul̼      3
# Lisel      3
# Laurine    3
# Wayne      3
#           ..
# Gaia       1
# Maggie     1
# Starlee    1
# Pas        1
# Sheila     1
# Name: Host_Name, Length: 204, dtype: int64

# %%
# Deleting both columns

del data1["Host_Id"]
del data1["Host_Name"]

# %%
data1.head(4)
# Out:
#   Neighbourhood_Group Neighbourhood  Latitude  Longitude        Room_Type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    Price($)  Minimum_Nights  Number_Of_Reviews          Last_Review  \
# 0       149               1                  9  2018-10-19 00:00:00
# 1       225               1                 45  2019-05-21 00:00:00
# 2       150               3                  0                    0
# 3        89               1                270  2019-07-05 00:00:00
#
#    Reviews_Per_Month  Calculated_Host_Listings_Count  Availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# ...

# %%
del data1["Latitude"]

# %%
del data1["Longitude"]

# %% [markdown]
# ## Barplot :
#
# ### Here we are checking that what are the most popular neighborhoods for Airbnb listings in NYC.
#
#     We are using here column "Neighbourhood_group" and after grouping the data based on this column we are dividing the
#     groups on basis of "Room_type" and and then checking their "value_counts".

# %%
print(data1.groupby("Neighbourhood_Group")["Room_Type"].value_counts())

plt.figure(figsize=(8,4))
sns.countplot(data=data1,x="Neighbourhood_Group",hue="Room_Type")
plt.xticks(fontsize=9)
plt.title("Most Popular neighbourhood",fontsize=13.5,color="green")
plt.xlabel(xlabel=None,loc=None)
plt.legend(fontsize="small",loc='upper right')
plt.show()
# Out:
# Neighbourhood_Group  Room_Type
# Bronx                Private room        2
# Brooklyn             Entire home/apt    58
#                      Private room       53
# Manhattan            Entire home/apt    71
#                      Private room       51
#                      Shared room         2
# Queens               Private room        6
#                      Entire home/apt     5
# Staten Island        Private room        1
# Name: Room_Type, dtype: int64

# %% [markdown]
#     From here we can check that what is the most Popular neighbourhood for Airbnb listings in NYC.Some conclusions from here
#     1. It is quite clear from here that for 'Private rooms' both Manhattan and Brooklyn are equally favourite.
#     2. For entire Home or apartment 'Manhattan' is more favourite thatn brooklyn.
#     3. In Manhattan shared rooms are also available.

# %% [markdown]
# ## Categorical Plot :
#
# ### Here we are checking for Price of rooms in different neighbourhood.
#
#     We are using here "Neighbourhood_Group" and "Price($)" columns to draw a Categorical Plot. Here we further devide those
#     categories on the basis of "Room_Type"

# %%
"""From here we can draw conclusion that all the prices are fare, and there is one price which is extreme, but it doesn't 
seems like outlier."""

sns.catplot(data=data1,x="Neighbourhood_Group",y="Price($)",hue="Room_Type",height=5.5,aspect=1.3)
plt.title("Price of rooms based on neighbourhood",fontsize=13.5,color="green")
plt.xlabel(xlabel=None,loc=None)
plt.show()

# %% [markdown]
# ## Pie Chart :
#
# ### Here we are checking for Type of room with most reviews.
#
#     We are using here calculating "Number_Of_Reviews" with respect to "Room_Type" to get the idea about most popular room type.

# %%
print(data1.groupby("Room_Type")["Number_Of_Reviews"].sum())

plt.pie(x=data1.groupby("Room_Type")["Number_Of_Reviews"].sum().tolist(),
        labels=data1.groupby("Room_Type")["Number_Of_Reviews"].sum().index,
       autopct='%1.1f%%',colors=["C8","C9","r"])
# Out:
# Room_Type
# Entire home/apt    12033
# Private room       13501
# Shared room          224
# Name: Number_Of_Reviews, dtype: int64
# ([<matplotlib.patches.Wedge at 0x23074770160>,
# ...
#  [Text(0.11329995966373438, 1.094149495791227, 'Entire home/apt'),
#   Text(-0.14314654151968353, -1.0906461697777854, 'Private room'),
#   Text(1.0995895018196122, -0.030048751855894416, 'Shared room')],
#  [Text(0.06179997799840056, 0.5968088158861238, '46.7%'),
#   Text(-0.0780799317380092, -0.5948979107878828, '52.4%'),
#   Text(0.5997760919016066, -0.016390228285033316, '0.9%')])

# %% [markdown]
#     From here we can draw the conclusion that most of the reviews are for private room only. That means more people are
#     using Private rooms.

# %% [markdown]
# ## Violin plot :
#
# ### Here we are trying to look for Rooms availability based on neighbourhood.
#
#     We are checking here that in which city rooms are available for most of the year. Here we are using Violin plot
#     for that purpose. We further divide these violin plots into subcategories of different room types

# %%
print(data1.groupby(["Neighbourhood_Group","Room_Type"])["Availability_365"].count())

plt.figure(figsize=(12,5))
sns.violinplot(data=data1,x="Neighbourhood_Group",y="Availability_365",hue="Room_Type")
plt.title("Reviews for Rooms based on neighbourhood",fontsize=13.5,color="green")
plt.xlabel(xlabel=None,loc=None)
plt.show()
# Out:
# Neighbourhood_Group  Room_Type
# Bronx                Private room        2
# Brooklyn             Entire home/apt    58
#                      Private room       53
# Manhattan            Entire home/apt    71
#                      Private room       51
#                      Shared room         2
# Queens               Entire home/apt     5
#                      Private room        6
# Staten Island        Private room        1
# Name: Availability_365, dtype: int64

# %% [markdown]
#     From here we can draw the conclustion that, Manhattan each type of rooms are available for most of the year

# %% [markdown]
# ## Pair Plot :
#
# ### Here we are checking for relatability of different features with each other.

# %%
sns.pairplot(data=data1,hue="Neighbourhood_Group")

# %% [markdown]
# ## Working with second dataframe -

# %%
# Importing the second dataframe

data2 = pd.read_excel("HRDataset_v14.xlsx")

data2.head(5)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
# Looking at the size of dataset

data2.shape
# Out:
# (311, 36)

# %%
# Removing unsuefull column

del data2["Employee_Name"]
del data2["EmpID"]

# %%
# Checking for null values

data2.isnull().sum()
# Out:
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# RecruitmentSource               0
# ...

# %%
data2.columns.tolist()
# Out:
# ['MarriedID',
#  'MaritalStatusID',
#  'GenderID',
#  'EmpStatusID',
#  'DeptID',
#  'PerfScoreID',
#  'FromDiversityJobFairID',
#  'Salary',
#  'Termd',
#  'PositionID',
#  'Position',
#  'State',
#  'Zip',
#  'DOB',
#  'Sex',
#  'MaritalDesc',
#  'CitizenDesc',
#  'HispanicLatino',
#  'RaceDesc',
#  'DateofHire',
#  'DateofTermination',
#  'TermReason',
#  'EmploymentStatus',
#  'Department',
#  'ManagerName',
#  'ManagerID',
#  'RecruitmentSource',
#  'PerformanceScore',
#  'EngagementSurvey',
#  'EmpSatisfaction',
#  'SpecialProjectsCount',
#  'LastPerformanceReview_Date',
#  'DaysLateLast30',
#  'Absences']

# %% [markdown]
# #### As we can see from here that there are some column which looks like they are representing the same data.

# %%
# Looking at the categories for Married id

data2["MarriedID"].value_counts()
# Out:
# 0    187
# 1    124
# Name: MarriedID, dtype: int64

# %%
# Replacing 0 and 1 with "married" and "unmarried" 

data2["MarriedID"].replace({1:"Married",0:"Not_married"},inplace=True)

# %%
# There are two columns representing same type of data with same number of categories

data2["MaritalStatusID"].value_counts()
# Out:
# 0    137
# 1    124
# 2     30
# 3     12
# 4      8
# Name: MaritalStatusID, dtype: int64

# %%
data2["MaritalDesc"].value_counts()
# Out:
# Single       137
# Married      124
# Divorced      30
# Separated     12
# Widowed        8
# Name: MaritalDesc, dtype: int64

# %%
# removing one column with numerical categories

del data2["MaritalStatusID"]

# %%
# There are two columns representing same type of data with same number of categories

data2["EmpStatusID"].value_counts()
# Out:
# 1    184
# 5     88
# 3     14
# 4     14
# 2     11
# Name: EmpStatusID, dtype: int64

# %%
data2["EmploymentStatus"].value_counts()
# Out:
# Active                    207
# Voluntarily Terminated     88
# Terminated for Cause       16
# Name: EmploymentStatus, dtype: int64

# %%
# removing one column with numerical categories

del data2["EmpStatusID"]

# %%
# There are two columns representing same type of data with same number of categories

data2["DeptID"].value_counts()
# Out:
# 5    208
# 3     50
# 6     32
# 4     10
# 1     10
# 2      1
# Name: DeptID, dtype: int64

# %%
data2["Department"].value_counts()
# Out:
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: Department, dtype: int64

# %%
# removing one column with numerical categories
del data2["DeptID"]

# %%
data2["PerfScoreID"].value_counts()
# Out:
# 3    243
# 4     37
# 2     18
# 1     13
# Name: PerfScoreID, dtype: int64

# %%
data2["PerformanceScore"].value_counts()
# Out:
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13
# Name: PerformanceScore, dtype: int64

# %%
del data2["PerfScoreID"]

# %%
data2["FromDiversityJobFairID"].value_counts()
# Out:
# 0    282
# 1     29
# Name: FromDiversityJobFairID, dtype: int64

# %%
data2["FromDiversityJobFairID"].replace({1:"Yes",0:"No"},inplace=True)

# %%
data2["Termd"].value_counts()
# Out:
# 0    207
# 1    104
# Name: Termd, dtype: int64

# %%
data2["Termd"].replace({1:"Yes",0:"No"},inplace=True)

# %%
data2["PositionID"].value_counts()
# Out:
# 19    137
# 20     57
# 3      27
# 18     13
# 24      9
# 14      8
# 9       8
# 15      5
# 28      5
# 8       5
# 4       4
# 13      4
# 22      3
# 2       3
# 1       3
# 21      3
# 23      2
# 26      2
# 27      2
# 10      1
# 12      1
# 11      1
# 5       1
# 16      1
# 25      1
# 30      1
# 29      1
# 7       1
# 17      1
# 6       1
# Name: PositionID, dtype: int64

# %%
data2["Position"].value_counts()
# Out:
# Production Technician I         137
# Production Technician II         57
# Area Sales Manager               27
# Production Manager               14
# Software Engineer                10
# IT Support                        8
# Data Analyst                      7
# Sr. Network Engineer              5
# Database Administrator            5
# Network Engineer                  5
# BI Developer                      4
# Senior BI Developer               3
# Administrative Assistant          3
# Sales Manager                     3
# Accountant I                      3
# Sr. DBA                           2
# IT Manager - DB                   2
# Sr. Accountant                    2
# Director of Operations            1
# Shared Services Manager           1
# Data Analyst                      1
# Data Architect                    1
# Principal Data Architect          1
# IT Manager - Infra                1
# President & CEO                   1
# Enterprise Architect              1
# ...

# %%
del data2["PositionID"]

# %%
data2.head(4)
# Out:
#      MarriedID  GenderID FromDiversityJobFairID  Salary Termd  \
# 0  Not_married         1                     No   62506    No
# 1      Married         1                     No  104437   Yes
# 2      Married         0                     No   64955   Yes
# 3      Married         0                     No   64991    No
#
#                    Position State   Zip        DOB Sex  ...     ManagerName  \
# 0   Production Technician I    MA  1960 1983-07-10  M   ...  Michael Albert
# 1                   Sr. DBA    MA  2148 1975-05-05  M   ...      Simon Roup
# 2  Production Technician II    MA  1810 1988-09-19   F  ...  Kissy Sullivan
# 3   Production Technician I    MA  1886 1988-09-27   F  ...    Elijiah Gray
#
#   ManagerID RecruitmentSource PerformanceScore EngagementSurvey  \
# 0      22.0          LinkedIn          Exceeds             4.60
# 1       4.0            Indeed      Fully Meets             4.96
# 2      20.0          LinkedIn      Fully Meets             3.02
# ...

# %%
data2.columns
# Out:
# Index(['MarriedID', 'GenderID', 'FromDiversityJobFairID', 'Salary', 'Termd',
#        'Position', 'State', 'Zip', 'DOB', 'Sex', 'MaritalDesc', 'CitizenDesc',
#        'HispanicLatino', 'RaceDesc', 'DateofHire', 'DateofTermination',
#        'TermReason', 'EmploymentStatus', 'Department', 'ManagerName',
#        'ManagerID', 'RecruitmentSource', 'PerformanceScore',
#        'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount',
#        'LastPerformanceReview_Date', 'DaysLateLast30', 'Absences'],
#       dtype='object')

# %%
data2.loc[:,"Zip":].head(4)
# Out:
#     Zip        DOB Sex MaritalDesc CitizenDesc HispanicLatino RaceDesc  \
# 0  1960 1983-07-10  M       Single  US Citizen             No    White
# 1  2148 1975-05-05  M      Married  US Citizen             No    White
# 2  1810 1988-09-19   F     Married  US Citizen             No    White
# 3  1886 1988-09-27   F     Married  US Citizen             No    White
#
#   DateofHire DateofTermination         TermReason  ...     ManagerName  \
# 0 2011-07-05               NaT  N/A-StillEmployed  ...  Michael Albert
# 1 2015-03-30        2016-06-16      career change  ...      Simon Roup
# 2 2011-07-05        2012-09-24              hours  ...  Kissy Sullivan
# 3 2008-01-07               NaT  N/A-StillEmployed  ...    Elijiah Gray
#
#   ManagerID RecruitmentSource  PerformanceScore EngagementSurvey  \
# 0      22.0          LinkedIn           Exceeds             4.60
# 1       4.0            Indeed       Fully Meets             4.96
# ...

# %%
# Filling The nulls in the "DateofTermination" column as "Not Terminated"

data2["DateofTermination"].fillna(value="Not Terminated",inplace=True)

# %%
data2.head(4)
# Out:
#      MarriedID  GenderID FromDiversityJobFairID  Salary Termd  \
# 0  Not_married         1                     No   62506    No
# 1      Married         1                     No  104437   Yes
# 2      Married         0                     No   64955   Yes
# 3      Married         0                     No   64991    No
#
#                    Position State   Zip        DOB Sex  ...     ManagerName  \
# 0   Production Technician I    MA  1960 1983-07-10  M   ...  Michael Albert
# 1                   Sr. DBA    MA  2148 1975-05-05  M   ...      Simon Roup
# 2  Production Technician II    MA  1810 1988-09-19   F  ...  Kissy Sullivan
# 3   Production Technician I    MA  1886 1988-09-27   F  ...    Elijiah Gray
#
#   ManagerID RecruitmentSource PerformanceScore EngagementSurvey  \
# 0      22.0          LinkedIn          Exceeds             4.60
# 1       4.0            Indeed      Fully Meets             4.96
# 2      20.0          LinkedIn      Fully Meets             3.02
# ...

# %%
data2.insert(1,"MaritalDesc",data2.pop("MaritalDesc"))

# %%
data2.insert(3,"Sex",data2.pop("Sex"))

# %%
del data2["GenderID"]

# %%
data2.columns
# Out:
# Index(['MarriedID', 'MaritalDesc', 'Sex', 'FromDiversityJobFairID', 'Salary',
#        'Termd', 'Position', 'State', 'Zip', 'DOB', 'CitizenDesc',
#        'HispanicLatino', 'RaceDesc', 'DateofHire', 'DateofTermination',
#        'TermReason', 'EmploymentStatus', 'Department', 'ManagerName',
#        'ManagerID', 'RecruitmentSource', 'PerformanceScore',
#        'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount',
#        'LastPerformanceReview_Date', 'DaysLateLast30', 'Absences'],
#       dtype='object')

# %%
# Analyzing number of Male and female in the company

data2["Sex"].value_counts()
# Out:
# F     176
# M     135
# Name: Sex, dtype: int64

# %%
# Looking for mean salary for Male and Female

data2.groupby("Sex")["Salary"].mean()
# Out:
# Sex
# F     67786.727273
# M     70629.400000
# Name: Salary, dtype: float64

# %%
# Looking for number of Terminated employees according to Gender

data2.groupby(["Sex","Termd"])["Termd"].count()
# Out:
# Sex  Termd
# F    No       116
#      Yes       60
# M    No        91
#      Yes       44
# Name: Termd, dtype: int64

# %%
data2["Termd"].value_counts()
# Out:
# No     207
# Yes    104
# Name: Termd, dtype: int64

# %%
data2.nunique()
# Out:
# MarriedID                       2
# MaritalDesc                     5
# Sex                             2
# FromDiversityJobFairID          2
# Salary                        308
# Termd                           2
# Position                       32
# State                          28
# Zip                           158
# DOB                           307
# CitizenDesc                     3
# HispanicLatino                  4
# RaceDesc                        6
# DateofHire                    101
# DateofTermination              97
# TermReason                     18
# EmploymentStatus                3
# Department                      6
# ManagerName                    21
# ManagerID                      23
# RecruitmentSource               9
# PerformanceScore                4
# EngagementSurvey              119
# EmpSatisfaction                 5
# SpecialProjectsCount            9
# LastPerformanceReview_Date    137
# DaysLateLast30                  7
# ...

# %%
# statewise employee

data2["State"].value_counts()
# Out:
# MA    276
# CT      6
# TX      3
# VT      2
# UT      1
# AZ      1
# ND      1
# OR      1
# MT      1
# NV      1
# ID      1
# KY      1
# NC      1
# FL      1
# GA      1
# CO      1
# NY      1
# PA      1
# RI      1
# NH      1
# TN      1
# IN      1
# OH      1
# CA      1
# WA      1
# AL      1
# VA      1
# ME      1
# Name: State, dtype: int64

# %%
data2.columns
# Out:
# Index(['MarriedID', 'MaritalDesc', 'Sex', 'FromDiversityJobFairID', 'Salary',
#        'Termd', 'Position', 'State', 'Zip', 'DOB', 'CitizenDesc',
#        'HispanicLatino', 'RaceDesc', 'DateofHire', 'DateofTermination',
#        'TermReason', 'EmploymentStatus', 'Department', 'ManagerName',
#        'ManagerID', 'RecruitmentSource', 'PerformanceScore',
#        'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount',
#        'LastPerformanceReview_Date', 'DaysLateLast30', 'Absences'],
#       dtype='object')

# %%
data2["DateofHire"].value_counts()
# Out:
# 2011-01-10    14
# 2015-03-30    12
# 2015-01-05    11
# 2014-09-29    11
# 2011-07-05    10
#               ..
# 2011-03-07     1
# 2012-07-09     1
# 2016-01-05     1
# 2012-04-30     1
# 2010-04-10     1
# Name: DateofHire, Length: 101, dtype: int64

# %% [markdown]
# ## Histogram :
#
# ### Here we are looking for How many employee are getting hired each year.
#
#     For that we are using "DateofHire" columnn and counting the number of empoyees in that year.

# %%
# Number of Employees hired each year

plt.figure(figsize=(7,5))
ax=sns.histplot(x=data2["DateofHire"])
plt.title("Number of employee hired each year",fontsize=13,color="green")
plt.ylim(0,80)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x()+0.4, p.get_height()+5))
plt.show()

# %% [markdown]
#     From Here we can draw the conclusion that in 2012 max employee got hired.

# %% [markdown]
# ## Scatter Plot :
#
# ### Here we are looking for Saleries of both male and female.
#
#     For that we are using "Salary" column and categorizing them according to their Gender.

# %%
# Looking for salary recieved by most Male and Females

plt.figure(figsize=(8,6))
plt.figure(figsize=(12,4))
sns.scatterplot(data=data2,x=data2.index,y="Salary",hue="Sex")
plt.title("Salaries for Males and Females",fontsize=13,color="green")
plt.legend(bbox_to_anchor=(1.1,1))
plt.show()

# %% [markdown]
#     From here we can draw conclusion that most of the people are getting salary around 50000 to 100000.

# %% [markdown]
# ## Box plot :
#
# ### Here we are looking for Salaries of employee working in different departments.
#
#     For that we are using "Salary" of employees and categorizing them according to their "Department"

# %%
# Department wise salary

print(data2.groupby("Department")["Salary"].agg([np.min, np.mean, np.max]))

plt.figure(figsize=(12,5))
sns.boxplot(data=data2,x="Department",y="Salary")
plt.title("Department wise salary",fontsize=13,color="green")
plt.show()
# Out:
#                         amin           mean    amax
# Department
# Admin Offices          49920   71791.888889  106367
# Executive Office      250000  250000.000000  250000
# IT/IS                  50178   97064.640000  220450
# Production             45046   59953.545455  170500
# Sales                  55875   69061.258065  180000
# Software Engineering   77692   94989.454545  108987

# %% [markdown]
#     From here we can draw the conclusion that employee from "IT" department are having good salary

# %%
data2.head(3)
# Out:
#      MarriedID MaritalDesc Sex FromDiversityJobFairID  Salary Termd  \
# 0  Not_married      Single  M                      No   62506    No
# 1      Married     Married  M                      No  104437   Yes
# 2      Married     Married   F                     No   64955   Yes
#
#                    Position State   Zip        DOB  ...     ManagerName  \
# 0   Production Technician I    MA  1960 1983-07-10  ...  Michael Albert
# 1                   Sr. DBA    MA  2148 1975-05-05  ...      Simon Roup
# 2  Production Technician II    MA  1810 1988-09-19  ...  Kissy Sullivan
#
#   ManagerID RecruitmentSource PerformanceScore EngagementSurvey  \
# 0      22.0          LinkedIn          Exceeds             4.60
# 1       4.0            Indeed      Fully Meets             4.96
# 2      20.0          LinkedIn      Fully Meets             3.02
#
#   EmpSatisfaction SpecialProjectsCount LastPerformanceReview_Date  \
# 0               5                    0                 2019-01-17
# ...

# %% [markdown]
# ## Line Chart :
#
# ### Here we are looking at Absentee of Terminated and non-terminated employees from each department.
#
#     For that we are Drawing a line chart between "Absences" of employees and their "Department"

# %%
# Employees getting Terminated based on number of Absences

print(data2.groupby("Department")["Absences"].sum())

plt.figure(figsize=(10,5))
sns.lineplot(data=data2,x="Department",y="Absences",hue="Termd",palette="bright",estimator="mean")
plt.title("Absences of Employees",fontsize=13,color="green")
plt.show()
# Out:
# Department
# Admin Offices             78
# Executive Office          10
# IT/IS                    522
# Production              2120
# Sales                    358
# Software Engineering      96
# Name: Absences, dtype: int64

# %% [markdown]
# ## Heat Plot :
#
# ## Here we are trying to check the relationship between various features

# %%
# To check the corelation between columns

sns.heatmap(data2.corr(),annot=True)
# Out:
# <AxesSubplot:>
